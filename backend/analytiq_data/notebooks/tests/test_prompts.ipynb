# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../..")

# %%
import analytiq_data as ad
import asyncio
import os

# %%
ad.common.setup()

# %%
# Initialize the client
analytiq_client = ad.common.get_analytiq_client(env="test")

# %%
await ad.common.get_tag_id(analytiq_client, "test")

# %%
await ad.common.get_prompt_ids_by_tag(analytiq_client, "test")
