# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../..")

# %%
import asyncio
import os
import analytiq_data as ad

# %%
# Set the MONGODB_URI environment variable
os.environ["MONGODB_URI"] = "mongodb://localhost:27017"

# %%
# Initialize the client
analytiq_client = ad.common.get_analytiq_client(env="test")

# %%
doc_id = "68d5581d98c03d347ef54156"

# %%
msg = {
    "_id": "672839809af076d2a5f1d2e5",
    "msg": {
        "document_id": doc_id,
    }
}

# %%
await ad.msg_handlers.process_ocr_msg(analytiq_client, msg, force=False)

# %%
ad.common.get_ocr_json(analytiq_client, doc_id)

# %%
ad.common.get_ocr_text(analytiq_client, doc_id)

# %%
ad.common.get_ocr_text(analytiq_client, doc_id, page_idx=0)

# %%
ad.common.get_ocr_n_pages(analytiq_client, doc_id)

# %%
# Get the mistral key
api_key = await ad.llm.get_llm_key(analytiq_client, "mistral")

# %%
import os
from mistralai import Mistral

# %%
client = Mistral(api_key=api_key)

ocr_response = client.ocr.process(
    model="mistral-ocr-latest",
    document={
        "type": "document_url",
        "document_url": "https://arxiv.org/pdf/2201.04234"
    },
    include_image_base64=True
)

# %%
dict(ocr_response)
